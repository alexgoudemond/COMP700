# %% [markdown]
# # Isolation of Training Data
#
# This notebook will prepare the data for the next set of segmenation options - Neural Networks

# %% [markdown]
# ## Author: Alexander Goudemond, Student Number: 219030365

# %% [markdown]
# We cannot conduct Semantic Segmentation, and we can conduct Instance Segmentation! So this notebook will prepare our data to be used for training, and in another notebook we can train NN!

# %% [markdown]
# # Imports

# %%
from os import getcwd, walk, mkdir, stat, remove
from os import sep # used later on, in a function, to print directory contents
from os.path import exists, basename, join

from shutil import copyfile

from PIL.Image import fromarray
import cv2

import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Directory of Images

# %%
def get_manual_segmentation_directories(startPath):
    location_array = []
    acceptable_folders = ["SEG"]

    for root, dirs, files in walk(startPath):
        # skip this folder
        if ("OriginalZipped" in root):
            continue

        elif (root[ -3 : ] not in acceptable_folders):
            continue

        location_array.append(root)
    
    return location_array
###

# %%
current_directory = getcwd()
desired_directory = "..\\..\\Comp700_Processed_DataSets_1"

# %%
path = (current_directory + "\\" + desired_directory)
location_array = get_manual_segmentation_directories(path)

# %%
# first 10
print( location_array[0:10] ) 
print("Number of folders:", len( location_array ) )
# Out:
# ['c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG', 'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG', 'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\02_GT\\SEG', 'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\02_ST\\SEG', 'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-MuSC\\BF-C2DL-MuSC\\01_GT\\SEG', 'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-MuSC\\BF-C2DL-MuSC\\01_ST\\SEG', 'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-MuSC\\BF-C2DL-MuSC\\02_GT\\SEG', 'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-MuSC\\BF-C2DL-MuSC\\02_ST\\SEG', 'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\DIC-C2DH-HeLa\\DIC-C2DH-HeLa\\01_GT\\SEG', 'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\DIC-C2DH-HeLa\\DIC-C2DH-HeLa\\01_ST\\SEG']
# Number of folders: 36

# %% [markdown]
# We are now in a position where we can investigate the quantity of pictures inside each of those 36 folders. These 36 folders act as the Memo for our dataset, so collecting the names together will allow us to fetch the relevant images as our training images:

# %%
# loop through location_array, looking at the number of images:

image_quantities = []

for item in location_array:
    for root, dirs, files in walk(item):
        image_quantities.append(len(files))

image_quantities[0:10]
# Out:
# [49, 1764, 8, 1764, 50, 1376, 50, 1376, 9, 84]

# %%
# use image_quantities and location_array to generate a collection of paths for each image

y_training_data_paths = []
temp_array = []

for item in location_array:

    for root, dirs, files in walk(item):
        # temp_array = files
        for name in files:
            temp_array.append(item + "\\" + name)

    y_training_data_paths.append(temp_array)
    temp_array = [] # reset

# %%
y_training_data_paths
# Out:
# [['c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg0058.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg0108.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg0126.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg0175.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg0183.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg0218.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg0332.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg0347.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg0359.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg0402.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg0473.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg0475.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg0528.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg0659.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg0701.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg0713.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg0731.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg0760.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg0806.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg0838.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg0868.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg0871.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg0902.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg0930.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg0932.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg0965.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg0988.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg0990.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg1122.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg1162.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg1170.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg1199.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg1219.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg1357.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg1369.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg1397.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg1460.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg1468.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg1471.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg1476.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg1489.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg1490.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg1528.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg1558.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg1567.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg1583.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg1618.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg1707.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG\\man_seg1743.png'],
#  ['c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0000.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0001.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0002.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0003.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0004.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0005.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0006.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0007.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0008.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0009.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0010.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0011.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0012.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0013.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0014.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0015.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0016.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0017.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0018.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0019.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0020.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0021.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0022.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0023.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0024.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0025.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0026.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0027.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0028.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0029.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0030.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0031.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0032.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0033.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0034.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0035.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0036.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0037.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0038.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0039.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0040.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0041.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0042.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0043.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0044.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0045.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0046.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0047.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0048.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0049.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0050.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0051.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0052.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0053.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0054.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0055.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0056.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0057.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0058.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0059.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0060.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0061.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0062.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0063.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0064.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0065.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0066.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0067.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0068.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0069.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0070.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0071.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0072.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0073.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0074.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0075.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0076.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0077.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0078.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0079.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0080.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0081.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0082.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0083.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0084.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0085.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0086.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0087.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0088.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0089.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0090.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0091.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0092.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0093.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0094.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0095.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0096.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0097.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0098.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0099.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0100.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0101.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0102.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0103.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0104.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0105.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0106.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0107.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0108.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0109.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0110.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0111.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0112.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0113.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0114.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0115.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0116.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0117.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0118.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0119.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0120.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0121.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0122.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0123.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0124.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0125.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0126.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0127.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0128.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0129.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0130.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0131.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0132.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0133.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0134.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0135.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0136.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0137.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0138.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0139.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0140.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0141.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0142.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0143.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0144.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0145.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0146.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0147.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0148.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0149.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0150.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0151.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0152.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0153.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0154.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0155.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0156.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0157.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0158.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0159.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0160.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0161.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0162.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0163.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0164.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0165.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0166.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0167.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0168.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0169.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0170.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0171.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0172.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0173.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0174.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0175.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0176.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0177.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0178.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0179.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0180.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0181.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0182.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0183.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0184.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0185.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0186.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0187.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0188.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0189.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0190.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0191.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0192.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0193.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0194.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0195.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0196.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0197.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0198.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0199.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0200.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0201.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0202.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0203.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0204.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0205.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0206.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0207.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0208.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0209.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0210.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0211.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0212.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0213.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0214.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0215.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0216.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0217.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0218.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0219.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0220.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0221.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0222.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0223.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0224.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0225.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0226.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0227.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0228.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0229.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0230.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0231.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0232.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0233.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0234.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0235.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0236.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0237.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0238.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0239.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0240.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0241.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0242.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0243.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0244.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0245.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0246.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0247.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0248.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0249.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0250.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0251.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0252.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0253.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0254.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0255.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0256.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0257.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0258.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0259.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0260.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0261.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0262.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0263.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0264.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0265.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0266.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0267.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0268.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0269.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0270.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0271.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0272.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0273.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0274.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0275.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0276.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0277.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0278.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0279.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0280.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0281.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0282.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0283.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0284.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0285.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0286.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0287.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0288.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0289.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0290.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0291.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG\\man_seg0292.png',
# ...
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg187.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg188.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg189.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg190.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg191.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg192.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg193.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg194.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg195.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg196.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg197.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg198.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg199.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg200.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg201.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg202.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg203.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg204.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg205.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg206.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg207.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg208.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg209.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg210.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg211.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg212.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg213.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg214.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg215.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg216.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg217.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg218.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg219.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg220.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg221.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg222.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg223.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg224.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg225.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg226.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg227.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg228.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg229.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg230.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg231.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg232.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg233.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg234.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg235.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg236.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg237.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg238.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg239.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg240.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg241.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg242.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg243.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg244.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg245.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg246.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg247.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg248.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg249.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg250.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg251.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg252.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg253.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg254.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg255.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg256.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg257.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg258.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg259.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg260.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg261.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg262.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg263.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg264.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg265.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg266.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg267.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg268.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg269.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg270.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg271.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg272.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg273.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg274.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg275.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg276.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg277.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg278.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg279.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg280.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg281.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg282.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg283.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg284.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg285.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg286.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg287.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg288.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg289.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg290.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg291.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg292.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg293.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg294.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg295.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg296.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg297.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg298.png',
#   'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\PhC-C2DL-PSC\\PhC-C2DL-PSC\\02_ST\\SEG\\man_seg299.png']]

# %% [markdown]
# Sanity check:

# %%
index = -1

for row in y_training_data_paths:
    index += 1
    if (len(row) != image_quantities[index]):
        print("Incompatible sizes!")

# %% [markdown]
# Fantastic!

# %% [markdown]
# We are now in a position where we can go through each of the elements in the y_training_data_paths and extract the number and extensions. This will then be used to fetch the image paths for our x_training_data_paths!

# %% [markdown]
# Now, it is worth noting that location_array sometimes has 2 folders of manually segmented images. So we actually have the opportunity for twice as many training sets!
#
# To recognize this:

# %%
location_array[0:10]
# Out:
# ['c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_GT\\SEG',
#  'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01_ST\\SEG',
#  'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\02_GT\\SEG',
#  'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\02_ST\\SEG',
#  'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-MuSC\\BF-C2DL-MuSC\\01_GT\\SEG',
#  'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-MuSC\\BF-C2DL-MuSC\\01_ST\\SEG',
#  'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-MuSC\\BF-C2DL-MuSC\\02_GT\\SEG',
#  'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-MuSC\\BF-C2DL-MuSC\\02_ST\\SEG',
#  'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\DIC-C2DH-HeLa\\DIC-C2DH-HeLa\\01_GT\\SEG',
#  'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\DIC-C2DH-HeLa\\DIC-C2DH-HeLa\\01_ST\\SEG']

# %% [markdown]
# So, we can split this into 2 arrays: st_array and gt_array!

# %%
gt_y_training_data_paths = []
st_y_training_data_paths = []
index = -1

for item in location_array:
    index += 1
    if ("_GT" in item):
        gt_y_training_data_paths.append(y_training_data_paths[index])
    else:
        st_y_training_data_paths.append(y_training_data_paths[index])

print("GT_ :", len(gt_y_training_data_paths))
print("ST_ :", len(st_y_training_data_paths))
# Out:
# GT_ : 20
# ST_ : 16

# %% [markdown]
# This is expected because not all of the data-sets have ST folders. To verify which folders are missing that data:
#
# -- Fluo-C2DL-Huh7 (x2)
#
# -- Fluo-N2DH-SIM+ (x2)

# %% [markdown]
# Let us now look at the x data:

# %%
def get_segmentation_directories(startPath):
    location_array = []
    acceptable_folders = ["\\01", "\\02"]

    for root, dirs, files in walk(startPath):
        # skip this folder
        if ("OriginalZipped" in root):
            continue

        elif (root[ -3 : ] not in acceptable_folders) or ("(1)" in root):
            continue

        location_array.append(root)
    
    return location_array
###

# %%
path = (current_directory + "\\" + desired_directory)
image_location_array = get_segmentation_directories(path)

print(image_location_array[0:10])
print(len(image_location_array))
# Out:
# ['c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\01', 'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-HSC\\BF-C2DL-HSC\\02', 'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-MuSC\\BF-C2DL-MuSC\\01', 'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\BF-C2DL-MuSC\\BF-C2DL-MuSC\\02', 'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\DIC-C2DH-HeLa\\DIC-C2DH-HeLa\\01', 'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\DIC-C2DH-HeLa\\DIC-C2DH-HeLa\\02', 'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\Fluo-C2DL-Huh7\\Fluo-C2DL-Huh7\\01', 'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\Fluo-C2DL-Huh7\\Fluo-C2DL-Huh7\\02', 'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\Fluo-C2DL-MSC\\Fluo-C2DL-MSC\\01', 'c:\\Users\\G5\\Documents\\GitHub\\COMP700\\..\\..\\Comp700_Processed_DataSets_1\\Fluo-C2DL-MSC\\Fluo-C2DL-MSC\\02']
# 20

# %% [markdown]
# Now all we have to do is loop through all images inside the respective paths in image_location_array, and extract the corresponding images!

# %%
def extractNumber(path, symbol):
    right_most_index = path.rfind(symbol)
    return (path[right_most_index + 1 : ])
###

print(y_training_data_paths[7][3])
extractNumber(y_training_data_paths[7][3], "g")
# Out:
# c:\Users\G5\Documents\GitHub\COMP700\..\..\Comp700_Processed_DataSets_1\BF-C2DL-MuSC\BF-C2DL-MuSC\02_ST\SEG\man_seg0003.png
# ''

# %%
image_number = ""
row = 0
column = 0

gt_x_training_data_paths = []
temp_array = []
count = -1

for item in image_location_array:
    count += 1
    # print(item)
    for root, dirs, files in walk(item):
        # print(files)
        for image in files:
            # initialize
            if (column == 0):
                image_number = extractNumber(gt_y_training_data_paths[row][column], "g")
                column += 1

            if (image_number in image):
                # print(count)
                temp_array.append(item + "\\" + image)

                # stop at final index position
                if (column < len(gt_y_training_data_paths[count]) ):
                    image_number = extractNumber(gt_y_training_data_paths[row][column], "g")
                    column += 1

        row += 1; column = 0
        gt_x_training_data_paths.append(temp_array)
        temp_array = []

    print("folder", (count+1), "of", len(image_location_array) , "complete")

    # _GT\\SEG
# Out:
# folder 1 of 20 complete
# folder 2 of 20 complete
# folder 3 of 20 complete
# folder 4 of 20 complete
# folder 5 of 20 complete
# folder 6 of 20 complete
# folder 7 of 20 complete
# folder 8 of 20 complete
# folder 9 of 20 complete
# folder 10 of 20 complete
# folder 11 of 20 complete
# folder 12 of 20 complete
# folder 13 of 20 complete
# folder 14 of 20 complete
# folder 15 of 20 complete
# folder 16 of 20 complete
# folder 17 of 20 complete
# folder 18 of 20 complete
# folder 19 of 20 complete
# folder 20 of 20 complete

# %% [markdown]
# Let's do a sanity check to ensure we have corresponding images:

# %%
for row in range(len(gt_x_training_data_paths)):
    print( len(gt_x_training_data_paths[row]), ":::", len(gt_y_training_data_paths[row]) )
# Out:
# 1764 ::: 49
# 1764 ::: 8
# 1375 ::: 50
# 1376 ::: 50
# 84 ::: 9
# 84 ::: 9
# 30 ::: 8
# 30 ::: 5
# 48 ::: 18
# 48 ::: 33
# 92 ::: 30
# 92 ::: 20
# 65 ::: 65
# 150 ::: 150
# 92 ::: 28
# 92 ::: 8
# 115 ::: 15
# 115 ::: 19
# 300 ::: 2
# 300 ::: 2

# %% [markdown]
# Let's repeat the process for st_x_training_data_paths:
#
# Recall that st_y_training_data_paths does not contain folders in every file location
#
# -- Fluo-C2DL-Huh7 (x2)
#
# -- Fluo-N2DH-SIM+ (x2)

# %%
image_number = ""
row = 0
column = 0

st_x_training_data_paths = []
temp_array = []
count = -1

for item in image_location_array:
    count += 1
    # print(item)
    for root, dirs, files in walk(item):
        # print(files)
        for image in files:

            # stop because these folders don't have ST folders
            test = image_location_array[count]
            if ("Fluo-C2DL-Huh7" in test) or ("Fluo-N2DH-SIM+" in test):
                break

            # initialize
            if (column == 0):
                image_number = extractNumber(st_y_training_data_paths[row][column], "g")
                column += 1

            if (image_number in image):
                # print(count)
                temp_array.append(item + "\\" + image)

                # stop at final index position
                if (column < len(st_y_training_data_paths[row]) ):
                    image_number = extractNumber(st_y_training_data_paths[row][column], "g")
                    column += 1

        column = 0
        if (len(temp_array) != 0):
            row += 1; 
            st_x_training_data_paths.append(temp_array)
            temp_array = []

    
    print("folder", (count+1), "of", len(image_location_array) , "complete")
# Out:
# folder 1 of 20 complete
# folder 2 of 20 complete
# folder 3 of 20 complete
# folder 4 of 20 complete
# folder 5 of 20 complete
# folder 6 of 20 complete
# folder 7 of 20 complete
# folder 8 of 20 complete
# folder 9 of 20 complete
# folder 10 of 20 complete
# folder 11 of 20 complete
# folder 12 of 20 complete
# folder 13 of 20 complete
# folder 14 of 20 complete
# folder 15 of 20 complete
# folder 16 of 20 complete
# folder 17 of 20 complete
# folder 18 of 20 complete
# folder 19 of 20 complete
# folder 20 of 20 complete

# %%
for row in range(len(st_x_training_data_paths)):
    print( len(st_x_training_data_paths[row]), ":::", len(st_y_training_data_paths[row]) )
# Out:
# 1764 ::: 1764
# 1764 ::: 1764
# 1375 ::: 1376
# 1376 ::: 1376
# 84 ::: 84
# 84 ::: 84
# 48 ::: 48
# 48 ::: 48
# 92 ::: 92
# 92 ::: 92
# 92 ::: 92
# 92 ::: 92
# 115 ::: 115
# 115 ::: 115
# 300 ::: 300
# 300 ::: 300

# %% [markdown]
# Okay! We are now in a position where we can save the contents of the images into dedicated locations! Let's have a folder called training data, which will be partitioned into ST and GT folders

# %% [markdown]
# What we can use to our advantage is to just cut off the filename for each of the file paths, and use that to try make directories!
#
# We can then write the content into the locations, making sure that each folder has a sub-folder called "x" and a sub-folder called "y"

# %% [markdown]
# Let us start with making the directories:

# %%
# create directories for work we create
def tryMakeDirectories(current_directory, list):
    path = ""
    for item in list:
        if (path == ""):
            path = item
        else:
            path = path + "\\" + item
            
        try:
            # join comes from os.path
            mkdir( join(current_directory, path) )
        except FileExistsError:
            # print("Folder already exists!")
            pass
        except:
            print("Unknown Error Encountered...")
###

def extractLeftHandSide(path, symbol):
    right_most_index = path.rfind(symbol)
    return (path[ : right_most_index ])
###

def extractRightHandSide(path, symbol):
    right_most_index = path.rfind(symbol)
    return (path[ right_most_index : ])
###

# %%
print(st_x_training_data_paths[0][0])
print(extractLeftHandSide( st_x_training_data_paths[0][0] , "\\" ))
# Out:
# c:\Users\G5\Documents\GitHub\COMP700\..\..\Comp700_Processed_DataSets_1\BF-C2DL-HSC\BF-C2DL-HSC\01\processed1_t0000.tif
# c:\Users\G5\Documents\GitHub\COMP700\..\..\Comp700_Processed_DataSets_1\BF-C2DL-HSC\BF-C2DL-HSC\01

# %%
# tryMakeDirectories(getcwd(), "..\\..\\COMP700_Training_ST\\BF-C2DL-HSC\\BF-C2DL-HSC\\01\\X".split("\\"))

# %% [markdown]
# We can also replace the 'Comp700_Processed_DataSets_1' keyword with a more valuable keyword, like "Training_ST" or "Training_GT"

# %%
# check the first 4 results from each array:
row = 1
print(extractLeftHandSide( st_x_training_data_paths[row][0] , "\\" ))
print(extractLeftHandSide( st_y_training_data_paths[row][0] , "\\" ))
print(extractLeftHandSide( gt_x_training_data_paths[row][0] , "\\" ))
print(extractLeftHandSide( gt_y_training_data_paths[row][0] , "\\" ))
# Out:
# c:\Users\G5\Documents\GitHub\COMP700\..\..\Comp700_Processed_DataSets_1\BF-C2DL-HSC\BF-C2DL-HSC\02
# c:\Users\G5\Documents\GitHub\COMP700\..\..\Comp700_Processed_DataSets_1\BF-C2DL-HSC\BF-C2DL-HSC\02_ST\SEG
# c:\Users\G5\Documents\GitHub\COMP700\..\..\Comp700_Processed_DataSets_1\BF-C2DL-HSC\BF-C2DL-HSC\02
# c:\Users\G5\Documents\GitHub\COMP700\..\..\Comp700_Processed_DataSets_1\BF-C2DL-HSC\BF-C2DL-HSC\02_GT\SEG

# %%
# we only need to use the x_training data as all the folders will correspond!

keyword = "COMP700_Training_ST"
dirsToMake = []

for row in st_x_training_data_paths:
    temp = row[0]                                           # get first path
    temp = extractRightHandSide(temp, "Comp700_Processed_DataSets_1")  # remove initial directorty
    temp = extractLeftHandSide(temp, "\\")                  # get path
    temp = temp.replace("Comp700_Processed_DataSets_1", keyword)       # replace
    temp = "..\\..\\" + temp                                # add missing stuff
    # print(temp)
    dirsToMake.append(temp + "\\" + "X")  
    dirsToMake.append(temp + "\\" + "Y")                   

# make directories
for item in dirsToMake:
    tryMakeDirectories(getcwd(), item.split("\\"))

# verify all exist
count = 0
for item in dirsToMake:
    if (exists(item)):
        count += 1
print("Total Directories needed: ", len(dirsToMake), "; Total Directories present: ", count, sep="")
# Out:
# Total Directories needed: 32; Total Directories present: 32

# %%
# we only need to use the x_training data as all the folders will correspond!

keyword = "COMP700_Training_GT"
dirsToMake = []

for row in gt_x_training_data_paths:
    temp = row[0]                                           # get first path
    temp = extractRightHandSide(temp, "Comp700_Processed_DataSets_1")  # remove initial directorty
    temp = extractLeftHandSide(temp, "\\")                  # get path
    temp = temp.replace("Comp700_Processed_DataSets_1", keyword)       # replace
    temp = "..\\..\\" + temp                                # add missing stuff
    # print(temp)
    dirsToMake.append(temp + "\\" + "X")  
    dirsToMake.append(temp + "\\" + "Y")                        

# make directories
for item in dirsToMake:
    tryMakeDirectories(getcwd(), item.split("\\"))

# verify all exist
count = 0
for item in dirsToMake:
    if (exists(item)):
        count += 1
print("Total Directories needed: ", len(dirsToMake), "; Total Directories present: ", count, sep="")
# Out:
# Total Directories needed: 40; Total Directories present: 40

# %% [markdown]
# WooHoo! We now have the directories we need for the training data! The next thing to do is to save the files into their corresponding positions!

# %% [markdown]
# Let's loop through the variables and save them to their locations using shutil:

# %%
def bulkCopy(list2D, keyword, keywordToReplace, folderName):
    destination = ""
    filename = ""
    for row in list2D:
        for item in row:

            destination = item.replace(keyword, keywordToReplace)
            destination = extractLeftHandSide(destination, "\\")
            destination = destination + "\\" + folderName

            # special check:
            if ("_ST\\SEG" in destination):
                destination = destination.replace("_ST\\SEG", "")
            elif ("_GT\\SEG" in destination):
                destination = destination.replace("_GT\\SEG", "")

            filename = extractNumber(item, "\\")

            # print(destination + "\t" + filename)

            #shutil.copyfile()
            copyfile(item, destination + "\\" + filename)
###

# %%
bulkCopy(st_x_training_data_paths, "Comp700_Processed_DataSets_1", "COMP700_Training_ST", "X")

# %%
bulkCopy(st_y_training_data_paths, "Comp700_Processed_DataSets_1", "COMP700_Training_ST", "Y")

# %%
bulkCopy(gt_x_training_data_paths, "Comp700_Processed_DataSets_1", "COMP700_Training_GT", "X")

# %%
bulkCopy(gt_y_training_data_paths, "Comp700_Processed_DataSets_1", "COMP700_Training_GT", "Y")

# %% [markdown]
# Awesome Sauce! We now have a dedicated training set!!
#
# Let us generate some videos to verify that the data corresponds:

# %% [markdown]
# # Video Generation

# %%
from moviepy.editor import clips_array, VideoFileClip
from IPython.display import Video

# %% [markdown]
# We need to generate a video for each row in st training as well as gt training
#
# We need a list of folder names, as well as a list of file dimensions:

# %%
# generate this for the videos!
def generateFoldersFrom2DList(list):
    folderNameArray = []

    for row in list:
        for item in row:
            # temp = item.replace
            
            temp = extractLeftHandSide(item, "\\0")
            temp = extractRightHandSide(temp, "\\")
            # print(temp)
            folderNameArray.append(temp[ 1 : ])
            break


    return (folderNameArray)
###

def getEvenElements(list):
    temp = []
    for i in range(len(list)):
        if (i % 2 == 0):
            temp.append(list[i])

    return temp
###

# %%
gt_folders = getEvenElements(generateFoldersFrom2DList(gt_x_training_data_paths))

gt_folders
# Out:
# ['BF-C2DL-HSC',
#  'BF-C2DL-MuSC',
#  'DIC-C2DH-HeLa',
#  'Fluo-C2DL-Huh7',
#  'Fluo-C2DL-MSC',
#  'Fluo-N2DH-GOWT1',
#  'Fluo-N2DH-SIM+',
#  'Fluo-N2DL-HeLa',
#  'PhC-C2DH-U373',
#  'PhC-C2DL-PSC']

# %%
st_folders = getEvenElements(generateFoldersFrom2DList(st_x_training_data_paths))

st_folders
# Out:
# ['BF-C2DL-HSC',
#  'BF-C2DL-MuSC',
#  'DIC-C2DH-HeLa',
#  'Fluo-C2DL-MSC',
#  'Fluo-N2DH-GOWT1',
#  'Fluo-N2DL-HeLa',
#  'PhC-C2DH-U373',
#  'PhC-C2DL-PSC']

# %% [markdown]
# We now have our folders for GT and ST! Next, we need image dimensions:
#
# We already know from 003 that the images have consistent dimensions. So, we fetch the dimensions using the first image from each folder:

# %%
def getDimensionsFrom2DList(list):
    image_size_array = []

    # only need dimensions of first image as all dimensions same!
    for row in list:
        for item in row:
                img = cv2.imread( (item), cv2.IMREAD_GRAYSCALE)
                (x, y) = img.shape

                image_size_array.append([x, y])
                break
                

    return (image_size_array)
###

# %%
gt_image_dimensions = getDimensionsFrom2DList(gt_x_training_data_paths)

gt_image_dimensions
# Out:
# [[1010, 1010],
#  [1010, 1010],
#  [1036, 1070],
#  [1036, 1070],
#  [512, 512],
#  [512, 512],
#  [1024, 1024],
#  [1024, 1024],
#  [832, 992],
#  [782, 1200],
#  [1024, 1024],
#  [1024, 1024],
#  [690, 628],
#  [773, 739],
#  [700, 1100],
#  [700, 1100],
#  [520, 696],
#  [520, 696],
#  [576, 720],
#  [576, 720]]

# %%
st_image_dimensions = getDimensionsFrom2DList(st_x_training_data_paths)

st_image_dimensions
# Out:
# [[1010, 1010],
#  [1010, 1010],
#  [1036, 1070],
#  [1036, 1070],
#  [512, 512],
#  [512, 512],
#  [832, 992],
#  [782, 1200],
#  [1024, 1024],
#  [1024, 1024],
#  [700, 1100],
#  [700, 1100],
#  [520, 696],
#  [520, 696],
#  [576, 720],
#  [576, 720]]

# %% [markdown]
# We can now generate videos!

# %% [markdown]
# Before we can progress, we need to extend st_folders and gt_folders to have 16 and 20 elements, instead of 8 and 10:

# %%
st_folders_complete = []

for item in st_folders:
    st_folders_complete.append(item + "_01")
    st_folders_complete.append(item + "_02")

gt_folders_complete = []

for item in gt_folders:
    gt_folders_complete.append(item + "_01")
    gt_folders_complete.append(item + "_02")

print(len(st_folders_complete))
print(len(gt_folders_complete))
# Out:
# 16
# 20

# %%
def generateVideosFromArray(current_directory, desired_folder, list, folderName, dimensions, tag, useColour):
    # only progress if files don't exist
    makeVideos = False

    if (exists(current_directory + "\\" + desired_folder)):
        # Now, go to directory and verify all is there
        path = walk(current_directory + "\\" + desired_folder)

        count = 0
        for root, dirs, files in path:
            for item in files:
                count += 1

        if (count == len(list)):
            print("All Videos exist already!")
        else:
            print("Not all Videos exist")
            makeVideos = True

    if (makeVideos):
        i = -1
        output_video = cv2.VideoWriter()
        frames_per_second = 10
        picNum = 0
        fileName = ""

        # Generates Colour Videos
        for row in list:
            for item in row:
                    picNum += 1
                    # update on first element only
                    if  (picNum == 1):
                        i += 1

                        size = (dimensions[i][1], dimensions[i][0] ) # notice order
                        fileName = tag + folderName[i] + ".mp4"
                        
                        output_video = cv2.VideoWriter(
                            fileName, 
                            cv2.VideoWriter_fourcc(*'DIVX'), 
                            frames_per_second, 
                            size,
                            isColor=useColour # either True or False
                        )
                    
                    img = plt.imread(item) 
                    plt.imsave("temp.jpg", img, cmap='gray')
                    img = cv2.imread( "temp.jpg", cv2.IMREAD_GRAYSCALE)
                      
                    output_video.write(img)

            picNum = 0 # reset

            if (len(fileName) != 0):
                cv2.destroyAllWindows()
                output_video.release()
                print("Video finished for ", fileName, sep="")
    
    # remove at end
    if (exists("temp.jpg")):
        remove("temp.jpg")
###

# from os.path import join
from shutil import move # moves and replaces files

def moveBulkVideos(current_directory, desired_folder, names_list):
    moveVids = False

    try:
        # only progress if files don't exist
        if (exists(current_directory + "\\" + desired_folder)):
            print("Directory already exists!")

            path = walk(current_directory + "\\" + desired_folder)

            count = 0
            for root, dirs, files in path:
                for item in files:
                    count += 1

            if (count == len(names_list)):
                print("All Videos Already Exist!")
            else:
                print("Not all Videos in desired directory")
                moveVids = True
                
        if (moveVids):
            # local function
            tryMakeDirectory(current_directory, desired_folder)

            path = walk(current_directory)

            for root, dirs, files in path:
                for item in files:
                    if (".mp4" in item):
                        new_destination = current_directory + "\\" + desired_folder
                        path1 = join(current_directory, item)
                        path2 = join(new_destination, item)
                        move(path1, path2) # should overwrite existing data

            # Now, go to directory and verify all is there
            path = walk(current_directory + "\\" + desired_folder)

            count = 0
            for root, dirs, files in path:
                for item in files:
                    count += 1

            if (count == len(names_list)):
                print("All Videos Moved Successfully!")
            else:
                print("Not all Videos Moves Successfully")
    except FileNotFoundError:
        pass
    except:
        print("Unknown Error Encountered...")
###

# create directory for work we create
def tryMakeDirectory(current_directory, destination_directory):
    try:
        # join comes from os.path
        mkdir( join(current_directory, destination_directory) )
    except FileExistsError:
        # print("Folder already exists!")
        pass
    except:
        print("Unknown Error Encountered...")
###

# %%
# tryMakeDirectory(getcwd(), "..\\..\\COMP700_Training_Videos")

# %% [markdown]
# Generate directories for videos:

# %%
tryMakeDirectories(getcwd(), ["..\\..\\COMP700_Training_Videos", "GT", "X"])
tryMakeDirectories(getcwd(), ["..\\..\\COMP700_Training_Videos", "GT", "Y"])
tryMakeDirectories(getcwd(), ["..\\..\\COMP700_Training_Videos", "ST", "X"])
tryMakeDirectories(getcwd(), ["..\\..\\COMP700_Training_Videos", "ST", "Y"])

# %%
generateVideosFromArray(getcwd(), "..\\..\\COMP700_Training_Videos\\ST\\X", st_x_training_data_paths, st_folders_complete, st_image_dimensions, "x_", False)
# Out:
# All Videos exist already!

# %%
moveBulkVideos(getcwd(), "..\\..\\COMP700_Training_Videos\\ST\\X", st_folders_complete)
# Out:
# Directory already exists!
# All Videos Already Exist!

# %%
generateVideosFromArray(getcwd(), "..\\..\\COMP700_Training_Videos\\ST\\Y", st_y_training_data_paths, st_folders_complete, st_image_dimensions, "y_", False)
# Out:
# All Videos exist already!

# %%
moveBulkVideos(getcwd(), "..\\..\\COMP700_Training_Videos\\ST\\Y", st_folders_complete)
# Out:
# Directory already exists!
# All Videos Already Exist!

# %%
generateVideosFromArray(getcwd(), "..\\..\\COMP700_Training_Videos\\GT\\X", gt_x_training_data_paths, gt_folders_complete, gt_image_dimensions, "x_", False)
# Out:
# All Videos exist already!

# %%
moveBulkVideos(getcwd(), "..\\..\\COMP700_Training_Videos\\GT\\X", gt_folders_complete)
# Out:
# Directory already exists!
# All Videos Already Exist!

# %%
generateVideosFromArray(getcwd(), "..\\..\\COMP700_Training_Videos\\GT\\Y", gt_y_training_data_paths, gt_folders_complete, gt_image_dimensions, "y_", False)
# Out:
# All Videos exist already!

# %%
moveBulkVideos(getcwd(), "..\\..\\COMP700_Training_Videos\\GT\\Y", gt_folders_complete)
# Out:
# Directory already exists!
# All Videos Already Exist!

# %% [markdown]
# # Video Comaprisons

# %% [markdown]
# What we need to do now is to stitch the X and Y data-sets together, to verify that all of the data has been grouped together successfully

# %% [markdown]
# We need to travel to our desired directory locations to access the videos:
#
# - ( getcwd(), "..\\..\\COMP700_Training_Videos\\GT\\X" )
# - ( getcwd(), "..\\..\\COMP700_Training_Videos\\GT\\Y" )
# - ( getcwd(), "..\\..\\COMP700_Training_Videos\\ST\\X" )
# - ( getcwd(), "..\\..\\COMP700_Training_Videos\\ST\\Y" )

# %%
def getVideoPaths(path):
    path = walk(path)

    video_paths = []

    for root, dirs, files in path:
        video_paths = files
        break
    
    return video_paths
###

def leftAppendStringToList(str, list):
    temp = []

    for item in list:
        temp.append(str + "\\" + item)

    return temp
###

# %%
gt_x_path = getcwd() + "\\..\\..\\" + "COMP700_Training_Videos\\GT\\X"
gt_y_path = getcwd() + "\\..\\..\\" + "COMP700_Training_Videos\\GT\\Y"
st_x_path = getcwd() + "\\..\\..\\" + "COMP700_Training_Videos\\ST\\X"
st_y_path = getcwd() + "\\..\\..\\" + "COMP700_Training_Videos\\ST\\Y"

gt_x_video_paths = getVideoPaths(gt_x_path)
gt_y_video_paths = getVideoPaths(gt_y_path)
st_x_video_paths = getVideoPaths(st_x_path)
st_y_video_paths = getVideoPaths(st_y_path)

full_gt_x_path = leftAppendStringToList(gt_x_path, gt_x_video_paths)
full_gt_y_path = leftAppendStringToList(gt_y_path, gt_y_video_paths)
full_st_x_path = leftAppendStringToList(st_x_path, st_x_video_paths)
full_st_y_path = leftAppendStringToList(st_y_path, st_y_video_paths)

# %% [markdown]
# We can use the x and y paths together! We also have some variables we can use for the file names: gt_folders_complete and st_folders_complete

# %%
def bulkStitch2Videos(test_directory, videoSourcePath1, videoSourcePath2, videoFiles1, videoFiles2, newLabels):
    name_array =    ["vid1.mp4", "vid2.mp4"]
    videoIndex = -1; count = 0

    for i in range(len(videoFiles1)):
        for j in range(2):
            if (j == 0):
                c = VideoFileClip(videoSourcePath1 + "\\" + videoFiles1[i])
            else:
                c = VideoFileClip(videoSourcePath2 + "\\" + videoFiles2[i])

            # getting only first 5 seconds
            clip = c.subclip(0, 5)

            # new clip with new duration
            new_clip = clip.set_duration(10)

            # reduce by 75%
            resized_clip = new_clip.resize(0.25)

            resized_clip.write_videofile(test_directory + "\\" + name_array[j])

            # new_clip.ipython_display(width=100)
            
        a = VideoFileClip(test_directory + "\\" + name_array[0])
        b = VideoFileClip(test_directory + "\\" + name_array[1])

        # now, stitch together!
        stitched_video = clips_array([[a, b]])

        stitched_video.write_videofile(test_directory + "\\" + newLabels[i] + ".mp4")
        
        resized_clip.close()
        
    try:
        a.close(); b.close()
    except:
        pass

    stitched_video.close()

    # at end, remove videos:
    for name in name_array:
        if (exists(test_directory + "\\" + name)):
            remove(test_directory + "\\" + name)
###

# %%
tryMakeDirectories(getcwd(), ["010_Training_Data_Videos", "GT"])
tryMakeDirectories(getcwd(), ["010_Training_Data_Videos", "ST"])

# %%
videoSource1 = getcwd() + "\\..\\..\\" + "COMP700_Training_Videos\\GT\\X"
videoSource2 = getcwd() + "\\..\\..\\" + "COMP700_Training_Videos\\GT\\Y"
test_directory = "010_Training_Data_Videos\\GT"

path = walk(test_directory)

for root, dirs, files in path:
    fileCollection = files
    break

if ( not ( len(fileCollection) == len(gt_folders_complete) ) ):
    bulkStitch2Videos(test_directory, videoSource1, videoSource2, gt_x_video_paths, gt_y_video_paths, gt_folders_complete)
else:
    print("Videos Already created!")
# Out:
# Videos Already created!

# %%
videoSource1 = getcwd() + "\\..\\..\\" + "COMP700_Training_Videos\\ST\\X"
videoSource2 = getcwd() + "\\..\\..\\" + "COMP700_Training_Videos\\ST\\Y"
test_directory = "010_Training_Data_Videos\\ST"

path = walk(test_directory)

for root, dirs, files in path:
    fileCollection = files
    break

if ( not ( len(fileCollection) == len(st_folders_complete) ) ):
    bulkStitch2Videos(test_directory, videoSource1, videoSource2, st_x_video_paths, st_y_video_paths, st_folders_complete)
else:
    print("Videos Already created!")
# Out:
# Videos Already created!

# %% [markdown]
# Fantastic! We are now certain that our training data has been generated successfully! We can verify it by playing a few videos here:

# %%
Video("010_Training_Data_Videos\\ST" + "\\" + st_folders_complete[0] + ".mp4")
# Out:
# <video src="010_Training_Data_Videos\ST\BF-C2DL-HSC_01.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
Video("010_Training_Data_Videos\\ST" + "\\" + st_folders_complete[5] + ".mp4")
# Out:
# <video src="010_Training_Data_Videos\ST\DIC-C2DH-HeLa_02.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
Video("010_Training_Data_Videos\\GT" + "\\" + st_folders_complete[2] + ".mp4")
# Out:
# <video src="010_Training_Data_Videos\GT\BF-C2DL-MuSC_01.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %%
Video("010_Training_Data_Videos\\GT" + "\\" + st_folders_complete[7] + ".mp4")
# Out:
# <video src="010_Training_Data_Videos\GT\Fluo-C2DL-MSC_02.mp4" controls  >
#       Your browser does not support the <code>video</code> element.
#     </video>

# %% [markdown]
# Okay! We are now in a position where we can start training some Neural Networks! We have successfully grouped our training data together, and next we can have a look at some Neural Networks for segmentation
